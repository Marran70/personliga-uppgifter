# %%
import numpy as np
from scipy.linalg import eig
from mtm026 import assem, Ke_balk, Ke_sigma_balk, extract_block

# Parametrar
P0 = 1.0; L1 = 5.0; L2 = 5.0
a = 0.05; t = 0.002; E = 200e9

# Tröghetsmomenter
Iv = (a**4 - (a - 2*t)**4) / 12
Ih = (a * (2*a)**3 - (a - 4*t) * (2*a - 4*t)**3) / 12
EIv = E * Iv
EIh = E * Ih

K = np.zeros((14, 14))
K_sig = np.zeros((14, 14))

Ke_v = Ke_balk(EIv, L2)
Ke_h = Ke_balk(EIh, L1)
Ke_sig_v = Ke_sigma_balk(P0, L2)

assem(K, Ke_v, dofs=[1, 2, 5, 6])
assem(K_sig, Ke_sig_v, dofs=[1, 2, 5, 6])

assem(K, Ke_v, dofs=[5, 6, 10, 11])
assem(K_sig, Ke_sig_v, dofs=[5, 6, 10, 11])

assem(K, Ke_v, dofs=[3, 4, 5, 8])

assem(K, Ke_v, dofs=[5, 8, 10, 13])

assem(K, Ke_h, dofs=[7, 6, 9, 8])

assem(K, Ke_h, dofs=[12, 11, 14, 13])

free_dofs = [3, 4, 5, 6, 5, 8, 10, 11, 10, 13]

k_red = extract_block(K, free_dofs, free_dofs)
k_red_sig = extract_block(K_sig, free_dofs, free_dofs)

alpha , vecs = eig(k_red, k_red_sig)

display(vecs)
print(np.min(alpha)*P0)
# Out:
# array([[ 6.43777181e-15,  1.00000000e+00,  8.35285916e-17,
#          4.77127872e-18, -2.26820701e-19,  2.13400871e-01,
#          2.13400871e-01, -2.13400871e-01, -2.13400871e-01,
#          1.20449715e-13],
#        [-1.90572506e-15,  1.22686231e-29, -1.00000000e+00,
#         -2.78608653e-18,  1.32447115e-19, -5.77388819e-18,
#         -1.11696650e-17,  5.77388819e-18,  1.11696650e-17,
#         -4.87115738e-14],
#        [-8.96818599e-03,  5.77351350e-17,  1.70908968e-17,
#          9.76257715e-19, -4.64100867e-20,  1.45077170e-15,
#         -1.42423954e-15, -1.45077170e-15,  1.42423954e-15,
#          8.96818599e-03],
#        [ 6.47093081e-17, -4.16583760e-31, -1.23318150e-31,
#         -7.04411811e-33,  3.34868680e-34,  4.88557856e-16,
#         -4.88557856e-16, -4.88557856e-16,  4.88557856e-16,
#          6.32071339e-16],
#        [ 8.96818599e-03, -5.77351350e-17, -1.70908968e-17,
#         -9.76257715e-19,  4.64100867e-20, -3.15708181e-16,
#          2.89176020e-16,  3.15708181e-16, -2.89176020e-16,
#         -8.96818599e-03],
#        [-1.08857880e-16,  7.00802192e-31,  2.07453190e-31,
#         -1.00000000e+00,  4.83475307e-19, -9.72685530e-01,
#         -9.72685530e-01,  9.72685530e-01,  9.72685530e-01,
#         -1.15037819e-15],
#        [ 7.07049907e-01, -4.55182597e-15, -1.34744273e-15,
#         -7.69679540e-17,  3.65896153e-18, -4.05686708e-16,
#         -1.68610335e-15,  4.05686708e-16,  1.68610335e-15,
#         -7.07049907e-01],
#        [ 1.23930021e-17, -7.97833197e-32, -2.36176547e-32,
#         -1.34907594e-33,  6.41334049e-35,  1.05211124e-16,
#         -1.05211124e-16, -1.05211124e-16,  1.05211124e-16,
#          3.15173364e-16],
#        [-7.07049907e-01,  4.55182597e-15,  1.34744273e-15,
#          7.69679540e-17, -3.65896153e-18,  1.66403394e-15,
#          4.27756118e-16, -1.66403394e-15, -4.27756118e-16,
#          7.07049907e-01],
#        [-5.17496925e-18,  3.33152712e-32,  9.86206857e-33,
#          5.63336182e-34,  1.00000000e+00,  9.13396265e-02,
#          9.13396265e-02, -9.13396265e-02, -9.13396265e-02,
#          1.32756246e-15]])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 45
#      43 display(a)
#      44 for i, dof in enumerate(free_dofs):
# ---> 45     print(f"FHG {dof}: phi = {np.real(a[i]):.4f}")
#      46 print(np.min(alpha)*P0)
#
# TypeError: unsupported format string passed to numpy.ndarray.__format__
