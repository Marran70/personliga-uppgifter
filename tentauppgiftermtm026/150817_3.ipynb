# %%
from mtm026 import *

S = np.array([
    [16, 0, -12],
    [0, 16, 15],
    [-12, 15, -16]
])

huvudspänningar, riktningar = eigh(S)
display(huvudspänningar)

sigma1 = huvudspänningar[0]
sigma2 = huvudspänningar[1]
sigma3 = huvudspänningar[2]

sigma_vonmises = np.sqrt(16**2 + 16**2 + 16**2 - 16**2 +16**2 + 16**2 +3*(12**2) + 3*(15**2))
sigma_tresca = np.max([np.abs(sigma1-sigma2), np.abs(sigma2-sigma3), np.abs(sigma3-sigma1)])


display(sigma_vonmises)
display(sigma_tresca)
# Out:
# array([-25.,  16.,  25.])
# 32.0
# 49.99999999999996
