# %%
import numpy as np
from mtm026 import *

S = np.array([
    [0, 0, 0],
    [0, 50, 6.4],
    [0, 6.4, 25]
    ])

huvudspänningar, riktningar = eig(S)
display(np.round(huvudspänningar, 3))
# Out:
# array([23.457+0.j, 51.543+0.j,  0.   +0.j])
