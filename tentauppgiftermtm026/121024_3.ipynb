# %%
from mtm026 import *

S = np.array([
    [120, 0, 40],
    [0, 70, 0],
    [40, 0 , 30]]
)

huvudspänningar, riktningar = eigh(S)
display(huvudspänningar)


n = np.array([0.9122, 0, -0.4097])

s = np.dot(n, S)

sigma = np.dot(n.T, s)

snorm = np.dot(s, s)

tau = np.sqrt(snorm - sigma**2)

display(sigma)
display(tau)
# Out:
# array([ 14.79202711,  70.        , 135.20797289])
# 74.99041629999999
# 3625.0740481526936
