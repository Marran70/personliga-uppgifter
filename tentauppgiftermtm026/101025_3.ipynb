# %%
from mtm026 import *

S=[
    [12, 0, 18],
    [0, 0, 0],
    [18, 0, 0]]

huvudspänningar, riktningar = eig(S)

huvudspäningarna = np.round(np.real(huvudspänningar), 3)
display(huvudspäningarna)
tresa = np.max(huvudspäningarna)
display(tresa)
# Out:
# array([ 24.974, -12.974,   0.   ])
# 24.974
