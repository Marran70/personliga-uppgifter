# %%
from mtm026 import *
S = np.array([
    [120, 60, 0],
    [60, 80, 0],
    [0, 0, 0]
])

huvudspänningar, riktningar = eig(S)
display(abs(huvudspänningar), riktningar)

taum = abs((np.max(huvudspänningar)-np.min(huvudspänningar))/2)


#tresca
sigma = max(abs(huvudspänningar[0]- huvudspänningar[1]), abs(huvudspänningar[1] - huvudspänningar[2]), abs(huvudspänningar[2]- huvudspänningar[0]))
display(sigma)

#von mises
sigma2 = (1/np.sqrt(2))*np.sqrt((huvudspänningar[0]- huvudspänningar[1])**2 + (huvudspänningar[1] - huvudspänningar[2])**2 + (huvudspänningar[2]- huvudspänningar[0])**2)
display(sigma2)
# Out:
# array([163.2455532,  36.7544468,   0.       ])
# array([[ 0.81124219, -0.58471028,  0.        ],
#        [ 0.58471028,  0.81124219,  0.        ],
#        [ 0.        ,  0.        ,  1.        ]])
# 163.2455532033676
# (148.32396974191326+0j)
