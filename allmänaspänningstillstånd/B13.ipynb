# %%
from mtm026 import *
S = np.array([
    [14, 0, 12],
    [0, 22, 0],
    [12, 0 , 31]
])

huvudspänningar, riktningar = eig(S)
display(abs(huvudspänningar), riktningar)

taum = abs((np.max(huvudspänningar)-np.min(huvudspänningar))/2)  #
# Out:
# array([ 7.79455883, 37.20544117, 22.        ])
# array([[-0.8882616 , -0.45933793,  0.        ],
#        [ 0.        ,  0.        ,  1.        ],
#        [ 0.45933793, -0.8882616 ,  0.        ]])

# %%
#tresca
