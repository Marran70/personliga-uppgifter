# %%
from mtm026 import *
S = np.array([
    [60, 0, 30],
    [0, 40, 20],
    [30, 20 ,25]
])

huvudspänningar, riktningar = eig(S)
display(huvudspänningar, riktningar)

taum = abs((np.max(huvudspänningar)-np.min(huvudspänningar))/2)
display(taum)
# Out:
# array([ 0.+0.j, 80.+0.j, 45.+0.j])
# array([[ 0.40824829, -0.80178373,  0.43643578],
#        [ 0.40824829, -0.26726124, -0.87287156],
#        [-0.81649658, -0.53452248, -0.21821789]])
# 40.00000000000003
